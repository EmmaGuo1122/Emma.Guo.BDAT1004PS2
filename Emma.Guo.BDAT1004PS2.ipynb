# %% [markdown]
# # Question 1#
# Consider the following Python module:
# <br>a = 0
# <br>def b():
# <br>global a
# <br>a = c(a)
# <br>def c(a):
# <br>return a + 2
# <br>After importing the module into the interpreter, you execute:
# <br>b()
# <br>b()
# <br>b()
# <br>a
# <br>?
# <br>What value is displayed when the last expression (a) is evaluated? Explain your answer by indicating what happens in every executed statement

# %%
a = 0
def b():
    global a
    a = c(a)
def c(a):
    return a + 2

# %%
b()

# %% [markdown]
# a=0 -> a=c(a) and excute c(a=0) -> a=0+2=2

# %%
b()

# %% [markdown]
# a=2 -> a=c(a) and excute c(a=2) -> a=2+2=4

# %%
b()

# %% [markdown]
# a=4 -> a=c(a) and excute c(a=4) -> a=4+2=6

# %%
a
# Out:
# 6

# %% [markdown]
# # Question 2 #
# Function fileLength(), given to you, takes the name of a file as input and returns the length of the file: <br> fileLength('midterm.py') 284 <br>fileLength('idterm.py') <br>Traceback (most recent call last): <br>File "<pyshell#34>", line 1, in <module> <br>fileLength('idterm.py') <br>File "/Users/me/midterm.py", line 3, in fileLength <br>infile = open(filename) <br>FileNotFoundError: [Errno 2] No such file or directory: 'idterm.py'<br>
# As shown above, if the file cannot be found by the interpreter or if it cannot be read as a text file, an exception will be raised. Modify function fileLength() so that a friendly message is printed instead: <br>fileLength('midterm.py') 358 <br> fileLength('idterm.py') File idterm.py not found.

# %%
def fileLength(file_name):
    try:
        file = open(file_name)
        contents = file.read()
        file.close()
        print(len(contents))
    except:
        print("File " + file_name+" not found")

# %%
fileLength("Filelength.txt")
# Out:
# 123

# %%
fileLength("midterm.py")
# Out:
# File midterm.py not found

# %% [markdown]
# # Question 3 #
# Write a class named Marsupial that can be used as shown below: <br> m = Marsupial() <br> m.put_in_pouch('doll') <br> m.put_in_pouch('firetruck') <br>m.put_in_pouch('kitten') <br> m.pouch_contents() ['doll', 'firetruck', 'kitten']

# %%
class Marsupial():
    def __init__(self):
        self.pouch=[]
    def put_in_pouch(self,stuff):
        self.pouch.append(stuff)
    def pouch_contents(self):
        print(self.pouch)

# %%
m = Marsupial()
m.put_in_pouch('doll')
m.put_in_pouch('firetruck')
m.put_in_pouch('kitten')

# %%
m.pouch_contents()
# Out:
# ['doll', 'firetruck', 'kitten']

# %% [markdown]
# Now write a class named Kangaroo as a subclass of Marsupial that inherits all the attributes of Marsupial and also:<br>
# a. extends the Marsupial __init__ constructor to take, as input, the coordinates x and y of the Kangaroo object,<br>
# b. supports method jump that takes number values dx and dy as input and moves the kangaroo by dx units along the x-axis and by dy units along the y-axis, and<br>
# c. overloads the __str__ operator so it behaves as shown below.
# <br> k = Kangaroo(0,0) <br> print(k) I am a Kangaroo located at coordinates (0,0) <br> k.put_in_pouch('doll') <br> k.put_in_pouch('firetruck') <br> k.put_in_pouch('kitten') <br> k.pouch_contents() ['doll', 'firetruck', 'kitten'] <br> k.jump(1,0) <br> k.jump(1,0) <br> k.jump(1,0) <br> print(k) I am a Kangaroo located at coordinates (3,0)

# %%
class Kangaroo(Marsupial):
    def __init__(self,x,y):
        Marsupial.__init__(self)
        self.x=x
        self.y=y
    def jump(self,dx,dy):
        self.x +=dx
        self.y +=dy
    def __str__(self):
        return 'I am a Kangaroo located at coordinates ({},{})'.format(self.x,self.y)

# %%
k = Kangaroo(0,0)
print(k)
# Out:
# I am a Kangaroo located at coordinates (0,0)

# %%
k.put_in_pouch('doll')
k.put_in_pouch('firetruck')
k.put_in_pouch('kitten')
k.pouch_contents()
# Out:
# ['doll', 'firetruck', 'kitten']

# %%
k.jump(1,0)
k.jump(1,0)
k.jump(1,0)
print(k)
# Out:
# I am a Kangaroo located at coordinates (3,0)

# %% [markdown]
# # Question 4 #
# Write function collatz() that takes a positive integer x as input and prints the Collatz sequence starting at x. A Collatz sequence is obtained by repeatedly applying this rule to the previous number x in the sequence:<br>
# x = { 𝑥/2 𝑖𝑓 𝑥 𝑖𝑠 𝑒𝑣𝑒𝑛<br>3𝑥+1 𝑖𝑓 𝑥 𝑖𝑠 𝑜𝑑𝑑<br>
# Your function should stop when the sequence gets to number 1. Your implementation must be recursive, without any loops.<br>

# %%
def collatz(x):   
    if x==1:
        print(1)
    elif x !=1 and x%2==1:
        print(int(x))
        collatz(3*x+1)    
    elif x%2 ==0:
        print(int(x))
        collatz(x/2)

# %%
collatz(1)
# Out:
# 1

# %%
collatz(10)
# Out:
# 10
# 5
# 16
# 8
# 4
# 2
# 1

# %% [markdown]
# # Question 5 #
# Write a recursive method binary() that takes a non-negative integer n and prints the binary representation of integer n.

# %%
def binary(n):
    if n == 0:
        return "0"
    elif n==1:
        return "1"
    else:
        return binary(n//2) + str(n%2)

# %%
binary(0)
# Out:
# '0'

# %%
binary(1)
# Out:
# '1'

# %%
binary(3)
# Out:
# '11'

# %%
binary(9)
# Out:
# '1001'

# %% [markdown]
# # Question 6 #
# Implement a class named HeadingParser that can be used to parse an HTML document, and retrieve and print all the headings in the document. You should implement your class as a subclass of HTMLParser, defined in Standard Library module html.parser. When fed a string containing HTML code, your class should print the headings, one per line and in the order in which they appear in the document. Each heading should be indented as follows: an h1 heading should have indentation 0, and h2 heading should have indentation 1, etc. Test your implementation using w3c.html.
# <br>infile = open('w3c.html')
# <br>content = infile.read()
# <br> infile.close()
# <br>hp = HeadingParser()
# <br> hp.feed(content)
# W3C Mission
# Principles

# %%
from html.parser import HTMLParser
import re

class HeadingParser(HTMLParser):
    heading = False
    indentation = 0
    def handle_starttag(self, tag, attrs):
        if re.match(r'h\d{1}',tag):
            self.heading =True
            
    def handle_data(self, data):
        if self.heading: 
            print(self.indentation * " " + data)
            self.indentation+=1
            
    def handle_endtag(self, tag):
        if re.match(r'h\d{1}',tag):
            self.heading =False

# %%
infile = open('w3c.html')
content = infile.read()
infile.close()
hp = HeadingParser()
hp.feed(content)
# Out:
# W3C Mission
#  Principles

# %% [markdown]
# # Question 7 #
# Implement recursive function webdir() that takes as input: a URL (as a string) and non-negative integers depth and indent. Your function should visit every web page reachable from the starting URL web page in depth clicks or less, and print each web page's URL. As shown below, indentation, specified by indent, should be used to indicate the depth of a URL. <br>webdir('http://reed.cs.depaul.edu/lperkovic/csc242/test1.html', 2, 0) http://reed.cs.depaul.edu/lperkovic/csc242/test1.html http://reed.cs.depaul.edu/lperkovic/csc242/test2.html http://reed.cs.depaul.edu/lperkovic/csc242/test4.html http://reed.cs.depaul.edu/lperkovic/csc242/test3.html http://reed.cs.depaul.edu/lperkovic/csc242/test4.html

# %%
from urllib.request import urlopen
from urllib.parse import urljoin
from html.parser import HTMLParser
class Collector(HTMLParser):
    'collects hyperlink URLs into a list'

    def __init__(self, url):
        'initializes parser, the url, and a list'
        HTMLParser.__init__(self)
        self.url = url
        self.links = []

    
    def handle_starttag(self, tag, attrs):
        'collects hyperlink URLs in their absolute format'
        if tag == 'a':
            for attr in attrs:
                if attr[0] == 'href':
                    # construct absolute URL
                    absolute = urljoin(self.url, attr[1])
                    if absolute[:4] == 'http': # collect HTTP URLs
                        self.links.append(absolute)
                        
    def getLinks(self):
        'returns hyperlinks URLs in their absolute format'
        return self.links

# %%
def webdir(url,depth,indent):    
    print("  "*indent + url)
    if depth ==0:
        return 
    else:
        resource = urlopen(url)
        content = resource.read().decode()
        collector = Collector(url)
        collector.feed(content)
        url_list =collector.getLinks()
        for urls in url_list:
            webdir(urls,depth-1,indent+1)

# %%
webdir("https://www.w3schools.com/html/",2,0)
# Out:
# https://www.w3schools.com/html/
#   https://www.w3schools.com
#     https://www.w3schools.com
#     https://profile.w3schools.com/log-in?redirect_url=https%3A%2F%2Fmy-learning.w3schools.com
#     https://courses.w3schools.com/
#     https://www.w3schools.com/cert/default.asp
#     https://shop.w3schools.com
#     https://www.w3schools.com/html/default.asp
#     https://www.w3schools.com/css/default.asp
#     https://www.w3schools.com/bootstrap/bootstrap_ver.asp
#     https://www.w3schools.com/w3css/default.asp
#     https://www.w3schools.com/colors/default.asp
#     https://www.w3schools.com/icons/default.asp
#     https://www.w3schools.com/graphics/default.asp
#     https://www.w3schools.com/graphics/svg_intro.asp
#     https://www.w3schools.com/graphics/canvas_intro.asp
#     https://www.w3schools.com/howto/default.asp
#     https://www.w3schools.com/sass/default.php
#     https://www.w3schools.com/ai/default.asp
#     https://www.w3schools.com/python/python_ml_getting_started.asp
#     https://www.w3schools.com/datascience/default.asp
#     https://www.w3schools.com/python/numpy/default.asp
#     https://www.w3schools.com/python/pandas/default.asp
#     https://www.w3schools.com/python/scipy/index.php
#     https://www.w3schools.com/python/matplotlib_intro.asp
#     https://www.w3schools.com/statistics/index.php
#     https://www.w3schools.com/xml/default.asp
#     https://www.w3schools.com/xml/ajax_intro.asp
#     https://www.w3schools.com/xml/dom_intro.asp
#     https://www.w3schools.com/xml/xml_dtd_intro.asp
#     https://www.w3schools.com/xml/schema_intro.asp
#     https://www.w3schools.com/xml/xsl_intro.asp
#     https://www.w3schools.com/xml/xpath_intro.asp
#     https://www.w3schools.com/xml/xquery_intro.asp
#     https://www.w3schools.com/js/default.asp
#     https://www.w3schools.com/jquery/default.asp
#     https://www.w3schools.com/react/default.asp
#     https://www.w3schools.com/angular/default.asp
#     https://www.w3schools.com/js/js_json_intro.asp
#     https://www.w3schools.com/js/js_ajax_intro.asp
#     https://www.w3schools.com/appml/default.asp
#     https://www.w3schools.com/w3js/default.asp
#     https://www.w3schools.com/python/default.asp
#     https://www.w3schools.com/java/default.asp
#     https://www.w3schools.com/cpp/default.asp
#     https://www.w3schools.com/cs/index.php
#     https://www.w3schools.com/r/default.asp
#     https://www.w3schools.com/kotlin/index.php
#     https://www.w3schools.com/go/index.php
#     https://www.w3schools.com/sql/default.asp
#     https://www.w3schools.com/mysql/default.asp
#     https://www.w3schools.com/php/default.asp
#     https://www.w3schools.com/asp/default.asp
#     https://www.w3schools.com/nodejs/default.asp
#     https://www.w3schools.com/nodejs/nodejs_raspberrypi.asp
#     https://www.w3schools.com/git/default.asp
#     https://www.w3schools.com/w3css/w3css_templates.asp
#     https://www.w3schools.com/browsers/default.asp
#     https://www.w3schools.com/cert/default.asp
#     https://www.w3schools.com/tryit/default.asp
#     https://www.w3schools.com/whatis/default.asp
#     https://www.w3schools.com/typingspeed/default.asp
#     https://www.w3schools.com/codegame/index.html
#     https://www.w3schools.com/cybersecurity/index.php
#     https://www.w3schools.com/accessibility/index.php
#     https://www.w3schools.com/ai/default.asp
#     https://www.w3schools.com/python/python_ml_getting_started.asp
#     https://www.w3schools.com/datascience/default.asp
#     https://www.w3schools.com/python/numpy/default.asp
#     https://www.w3schools.com/python/pandas/default.asp
#     https://www.w3schools.com/python/scipy/index.php
#     https://www.w3schools.com/python/matplotlib_intro.asp
#     https://www.w3schools.com/statistics/index.php
#     https://www.w3schools.com/xml/default.asp
#     https://www.w3schools.com/xml/ajax_intro.asp
#     https://www.w3schools.com/xml/dom_intro.asp
#     https://www.w3schools.com/xml/xml_dtd_intro.asp
#     https://www.w3schools.com/xml/schema_intro.asp
#     https://www.w3schools.com/xml/xsl_intro.asp
#     https://www.w3schools.com/xml/xpath_intro.asp
#     https://www.w3schools.com/xml/xquery_intro.asp
#     https://www.w3schools.com/tags/default.asp
#     https://www.w3schools.com/tags/ref_html_browsersupport.asp
#     https://www.w3schools.com/tags/ref_eventattributes.asp
#     https://www.w3schools.com/colors/default.asp
#     https://www.w3schools.com/tags/ref_attributes.asp
#     https://www.w3schools.com/tags/ref_canvas.asp
#     https://www.w3schools.com/graphics/svg_reference.asp
#     https://www.w3schools.com/graphics/google_maps_reference.asp
#     https://www.w3schools.com/cssref/default.asp
#     https://www.w3schools.com/cssref/css3_browsersupport.asp
#     https://www.w3schools.com/cssref/css_selectors.asp
#     https://www.w3schools.com/bootstrap/bootstrap_ref_all_classes.asp
#     https://www.w3schools.com/bootstrap4/bootstrap_ref_all_classes.asp
#     https://www.w3schools.com/w3css/w3css_references.asp
#     https://www.w3schools.com/icons/icons_reference.asp
#     https://www.w3schools.com/sass/sass_functions_string.php
#     https://www.w3schools.com/jsref/default.asp
#     https://www.w3schools.com/jsref/default.asp
#     https://www.w3schools.com/jquery/jquery_ref_overview.asp
#     https://www.w3schools.com/angular/angular_ref_directives.asp
#     https://www.w3schools.com/appml/appml_reference.asp
#     https://www.w3schools.com/w3js/w3js_references.asp
#     https://www.w3schools.com/python/python_reference.asp
#     https://www.w3schools.com/java/java_ref_keywords.asp
#     https://www.w3schools.com/sql/sql_ref_keywords.asp
#     https://www.w3schools.com/mysql/mysql_ref_functions.asp
#     https://www.w3schools.com/php/php_ref_overview.asp
#     https://www.w3schools.com/asp/asp_ref_response.asp
#     https://www.w3schools.com/xml/dom_nodetype.asp
#     https://www.w3schools.com/xml/dom_http.asp
#     https://www.w3schools.com/xml/xsl_elementref.asp
#     https://www.w3schools.com/xml/schema_elements_ref.asp
#     https://www.w3schools.com/charsets/default.asp
#     https://www.w3schools.com/charsets/ref_html_ascii.asp
#     https://www.w3schools.com/charsets/ref_html_ansi.asp
#     https://www.w3schools.com/charsets/ref_html_ansi.asp
#     https://www.w3schools.com/charsets/ref_html_8859.asp
#     https://www.w3schools.com/charsets/ref_html_symbols.asp
#     https://www.w3schools.com/charsets/ref_html_utf8.asp
#     https://www.w3schools.com/exercises/index.php
#     https://www.w3schools.com/html/html_exercises.asp
#     https://www.w3schools.com/css/css_exercises.asp
#     https://www.w3schools.com/js/js_exercises.asp
#     https://www.w3schools.com/sql/sql_exercises.asp
#     https://www.w3schools.com/mysql/mysql_exercises.asp
#     https://www.w3schools.com/php/php_exercises.asp
#     https://www.w3schools.com/python/python_exercises.asp
#     https://www.w3schools.com/python/numpy/numpy_exercises.asp
#     https://www.w3schools.com/python/pandas/pandas_exercises.asp
#     https://www.w3schools.com/python/scipy/scipy_exercises.php
#     https://www.w3schools.com/jquery/jquery_exercises.asp
#     https://www.w3schools.com/java/java_exercises.asp
#     https://www.w3schools.com/bootstrap/bootstrap_exercises.asp
#     https://www.w3schools.com/bootstrap4/bootstrap_exercises.asp
#     https://www.w3schools.com/cpp/cpp_exercises.asp
#     https://www.w3schools.com/cs/cs_exercises.asp
#     https://www.w3schools.com/r/r_exercises.asp
#     https://www.w3schools.com/kotlin/kotlin_exercises.php
#     https://www.w3schools.com/go/go_exercises.php
#     https://www.w3schools.com/git/git_exercises.asp
#     https://www.w3schools.com/quiztest/default.asp
#     https://www.w3schools.com/html/html_quiz.asp
#     https://www.w3schools.com/css/css_quiz.asp
#     https://www.w3schools.com/js/js_quiz.asp
#     https://www.w3schools.com/sql/sql_quiz.asp
#     https://www.w3schools.com/mysql/mysql_quiz.asp
#     https://www.w3schools.com/php/php_quiz.asp
#     https://www.w3schools.com/python/python_quiz.asp
#     https://www.w3schools.com/python/numpy/numpy_quiz.asp
#     https://www.w3schools.com/python/pandas/pandas_quiz.asp
#     https://www.w3schools.com/python/scipy/scipy_quiz.php
#     https://www.w3schools.com/jquery/jquery_quiz.asp
#     https://www.w3schools.com/java/java_quiz.asp
#     https://www.w3schools.com/bootstrap/bootstrap_quiz.asp
#     https://www.w3schools.com/bootstrap4/bootstrap_quiz.asp
#     https://www.w3schools.com/cpp/cpp_quiz.asp
#     https://www.w3schools.com/cs/cs_quiz.asp
#     https://www.w3schools.com/r/r_quiz.asp
#     https://www.w3schools.com/xml/xml_quiz.asp
#     https://www.w3schools.com/cybersecurity/cybersecurity_quiz.php
#     https://www.w3schools.com/accessibility/accessibility_quiz.php
#     https://courses.w3schools.com/
#     https://courses.w3schools.com/courses/html
#     https://courses.w3schools.com/courses/css
#     https://courses.w3schools.com/courses/javascript
#     https://courses.w3schools.com/programs/front-end
#     https://courses.w3schools.com/courses/sql
#     https://courses.w3schools.com/courses/python
#     https://courses.w3schools.com/courses/numpy-fundamentals
#     https://courses.w3schools.com/courses/pandas-fundamentals
#     https://courses.w3schools.com/courses/jquery
#     https://courses.w3schools.com/courses/php
#     https://courses.w3schools.com/courses/c-sharp
#     https://courses.w3schools.com/courses/cplusplus
#     https://courses.w3schools.com/courses/xml
#     https://courses.w3schools.com/courses/r-fundamentals
#     https://courses.w3schools.com/courses/introduction-to-cyber-security
#     https://courses.w3schools.com/courses/accessibility-fundamentals
#     https://www.w3schools.com/html/default.asp
#     https://www.w3schools.com/tags/default.asp
#     https://www.w3schools.com/html/tryit.asp?filename=tryhtml_default
#     https://www.w3schools.com/css/default.asp
#     https://www.w3schools.com/cssref/default.asp
#     https://www.w3schools.com/css/tryit.asp?filename=trycss_default
#     https://www.w3schools.com/js/default.asp
#     https://www.w3schools.com/jsref/default.asp
#     https://www.w3schools.com/js/tryit.asp?filename=tryjs_default
#     https://www.w3schools.com/python/default.asp
#     https://www.w3schools.com/python/python_reference.asp
#     https://www.w3schools.com/python/trypython.asp?filename=demo_indentation
#     https://www.w3schools.com/sql/default.asp
#     https://www.w3schools.com/sql/sql_ref_keywords.asp
#     https://www.w3schools.com/sql/trysql.asp?filename=trysql_select_where
#     https://www.w3schools.com/php/default.asp
#     https://www.w3schools.com/jquery/default.asp
#     https://www.w3schools.com/java/default.asp
#     https://www.w3schools.com/cpp/default.asp
#     https://www.w3schools.com/w3css/default.asp
#     https://www.w3schools.com/bootstrap/default.asp
#     https://www.w3schools.com/bootstrap4/default.asp
#     https://www.w3schools.com/cs/index.php
#     https://www.w3schools.com/r/default.asp
#     https://www.w3schools.com/kotlin/index.php
#     https://www.w3schools.com/mysql/default.asp
#     https://www.w3schools.com/nodejs/default.asp
#     https://www.w3schools.com/react/default.asp
#     https://www.w3schools.com/js/js_json.asp
#     https://www.w3schools.com/angular/default.asp
#     https://www.w3schools.com/w3js/default.asp
#     https://www.w3schools.com/xml/default.asp
#     https://www.w3schools.com/sass/default.php
#     https://www.w3schools.com/icons/default.asp
#     https://www.w3schools.com/css/css_rwd_intro.asp
#     https://www.w3schools.com/graphics/default.asp
#     https://www.w3schools.com/graphics/svg_intro.asp
#     https://www.w3schools.com/graphics/canvas_intro.asp
#     https://www.w3schools.com/nodejs/nodejs_raspberrypi.asp
#     https://www.w3schools.com/cybersecurity/index.php
#     https://www.w3schools.com/colors/default.asp
#     https://www.w3schools.com/git/default.asp
#     https://www.w3schools.com/python/matplotlib_intro.asp
#     https://www.w3schools.com/python/numpy/default.asp
#     https://www.w3schools.com/python/pandas/default.asp
#     https://www.w3schools.com/python/scipy/index.php
#     https://www.w3schools.com/asp/default.asp
#     https://www.w3schools.com/accessibility/index.php
#     https://www.w3schools.com/appml/default.asp
#     https://www.w3schools.com/go/index.php
#     https://www.w3schools.com/python/python_ml_getting_started.asp
#     https://www.w3schools.com/ai/default.asp
#     https://www.w3schools.com/statistics/index.php
#     https://www.w3schools.com/datascience/default.asp
#     https://www.w3schools.com/colors/colors_picker.asp
#     https://www.w3schools.com/codegame/index.html
#     https://www.w3schools.com/codegame/index.html
#     https://www.w3schools.com/exercises/index.php
#     https://www.w3schools.com/quiztest/default.asp
#     https://www.w3schools.com/w3css/w3css_templates.asp
#     https://www.w3schools.com/w3css/w3css_templates.asp
#     https://courses.w3schools.com/
#     https://www.w3schools.com/howto/default.asp
#     https://courses.w3schools.com/
#     https://www.w3schools.com/quiztest/default.asp
#     https://www.w3schools.com/exercises/index.php
#     https://courses.w3schools.com/
#     https://www.w3schools.com/quiztest/default.asp
#     https://www.w3schools.com/exercises/index.php
#     https://www.w3schools.com/forum/default.asp
#     https://www.w3schools.com/about/default.asp
#     https://www.w3schools.com/forum/default.asp
#     https://www.w3schools.com/about/default.asp
#     https://www.linkedin.com/company/w3schools.com/
#     https://www.instagram.com/w3schools.com_official/
#     https://www.facebook.com/w3schoolscom/
#     https://www.w3schools.com/about/about_copyright.asp
#     https://www.w3schools.com/about/about_privacy.asp
#     https://www.w3schools.com/about/about_copyright.asp
#     https://shop.w3schools.com/
#   https://profile.w3schools.com/log-in?redirect_url=https%3A%2F%2Fmy-learning.w3schools.com
#   https://courses.w3schools.com/
#     https://courses.w3schools.com/#content
#     https://courses.w3schools.com/
#     https://courses.w3schools.com/login
#     https://courses.w3schools.com/
#     https://www.instructure.com/policies/acceptable-use
#     https://www.instructure.com/policies/privacy/
#   https://www.w3schools.com/default.asp
#     https://www.w3schools.com
#     https://profile.w3schools.com/log-in?redirect_url=https%3A%2F%2Fmy-learning.w3schools.com
#     https://courses.w3schools.com/
#     https://www.w3schools.com/cert/default.asp
#     https://shop.w3schools.com
#     https://www.w3schools.com/html/default.asp
#     https://www.w3schools.com/css/default.asp
#     https://www.w3schools.com/bootstrap/bootstrap_ver.asp
#     https://www.w3schools.com/w3css/default.asp
#     https://www.w3schools.com/colors/default.asp
#     https://www.w3schools.com/icons/default.asp
#     https://www.w3schools.com/graphics/default.asp
#     https://www.w3schools.com/graphics/svg_intro.asp
#     https://www.w3schools.com/graphics/canvas_intro.asp
#     https://www.w3schools.com/howto/default.asp
#     https://www.w3schools.com/sass/default.php
#     https://www.w3schools.com/ai/default.asp
#     https://www.w3schools.com/python/python_ml_getting_started.asp
#     https://www.w3schools.com/datascience/default.asp
#     https://www.w3schools.com/python/numpy/default.asp
#     https://www.w3schools.com/python/pandas/default.asp
#     https://www.w3schools.com/python/scipy/index.php
#     https://www.w3schools.com/python/matplotlib_intro.asp
#     https://www.w3schools.com/statistics/index.php
#     https://www.w3schools.com/xml/default.asp
#     https://www.w3schools.com/xml/ajax_intro.asp
#     https://www.w3schools.com/xml/dom_intro.asp
#     https://www.w3schools.com/xml/xml_dtd_intro.asp
#     https://www.w3schools.com/xml/schema_intro.asp
#     https://www.w3schools.com/xml/xsl_intro.asp
#     https://www.w3schools.com/xml/xpath_intro.asp
#     https://www.w3schools.com/xml/xquery_intro.asp
#     https://www.w3schools.com/js/default.asp
#     https://www.w3schools.com/jquery/default.asp
#     https://www.w3schools.com/react/default.asp
#     https://www.w3schools.com/angular/default.asp
#     https://www.w3schools.com/js/js_json_intro.asp
#     https://www.w3schools.com/js/js_ajax_intro.asp
#     https://www.w3schools.com/appml/default.asp
#     https://www.w3schools.com/w3js/default.asp
#     https://www.w3schools.com/python/default.asp
#     https://www.w3schools.com/java/default.asp
#     https://www.w3schools.com/cpp/default.asp
#     https://www.w3schools.com/cs/index.php
#     https://www.w3schools.com/r/default.asp
#     https://www.w3schools.com/kotlin/index.php
#     https://www.w3schools.com/go/index.php
#     https://www.w3schools.com/sql/default.asp
#     https://www.w3schools.com/mysql/default.asp
#     https://www.w3schools.com/php/default.asp
#     https://www.w3schools.com/asp/default.asp
#     https://www.w3schools.com/nodejs/default.asp
#     https://www.w3schools.com/nodejs/nodejs_raspberrypi.asp
#     https://www.w3schools.com/git/default.asp
#     https://www.w3schools.com/w3css/w3css_templates.asp
#     https://www.w3schools.com/browsers/default.asp
#     https://www.w3schools.com/cert/default.asp
#     https://www.w3schools.com/tryit/default.asp
#     https://www.w3schools.com/whatis/default.asp
#     https://www.w3schools.com/typingspeed/default.asp
#     https://www.w3schools.com/codegame/index.html
#     https://www.w3schools.com/cybersecurity/index.php
#     https://www.w3schools.com/accessibility/index.php
#     https://www.w3schools.com/ai/default.asp
#     https://www.w3schools.com/python/python_ml_getting_started.asp
#     https://www.w3schools.com/datascience/default.asp
#     https://www.w3schools.com/python/numpy/default.asp
#     https://www.w3schools.com/python/pandas/default.asp
#     https://www.w3schools.com/python/scipy/index.php
#     https://www.w3schools.com/python/matplotlib_intro.asp
#     https://www.w3schools.com/statistics/index.php
#     https://www.w3schools.com/xml/default.asp
#     https://www.w3schools.com/xml/ajax_intro.asp
#     https://www.w3schools.com/xml/dom_intro.asp
#     https://www.w3schools.com/xml/xml_dtd_intro.asp
#     https://www.w3schools.com/xml/schema_intro.asp
#     https://www.w3schools.com/xml/xsl_intro.asp
#     https://www.w3schools.com/xml/xpath_intro.asp
#     https://www.w3schools.com/xml/xquery_intro.asp
#     https://www.w3schools.com/tags/default.asp
#     https://www.w3schools.com/tags/ref_html_browsersupport.asp
#     https://www.w3schools.com/tags/ref_eventattributes.asp
#     https://www.w3schools.com/colors/default.asp
#     https://www.w3schools.com/tags/ref_attributes.asp
#     https://www.w3schools.com/tags/ref_canvas.asp
#     https://www.w3schools.com/graphics/svg_reference.asp
#     https://www.w3schools.com/graphics/google_maps_reference.asp
#     https://www.w3schools.com/cssref/default.asp
#     https://www.w3schools.com/cssref/css3_browsersupport.asp
#     https://www.w3schools.com/cssref/css_selectors.asp
#     https://www.w3schools.com/bootstrap/bootstrap_ref_all_classes.asp
#     https://www.w3schools.com/bootstrap4/bootstrap_ref_all_classes.asp
#     https://www.w3schools.com/w3css/w3css_references.asp
#     https://www.w3schools.com/icons/icons_reference.asp
#     https://www.w3schools.com/sass/sass_functions_string.php
#     https://www.w3schools.com/jsref/default.asp
#     https://www.w3schools.com/jsref/default.asp
#     https://www.w3schools.com/jquery/jquery_ref_overview.asp
#     https://www.w3schools.com/angular/angular_ref_directives.asp
#     https://www.w3schools.com/appml/appml_reference.asp
#     https://www.w3schools.com/w3js/w3js_references.asp
#     https://www.w3schools.com/python/python_reference.asp
#     https://www.w3schools.com/java/java_ref_keywords.asp
#     https://www.w3schools.com/sql/sql_ref_keywords.asp
#     https://www.w3schools.com/mysql/mysql_ref_functions.asp
#     https://www.w3schools.com/php/php_ref_overview.asp
#     https://www.w3schools.com/asp/asp_ref_response.asp
#     https://www.w3schools.com/xml/dom_nodetype.asp
#     https://www.w3schools.com/xml/dom_http.asp
#     https://www.w3schools.com/xml/xsl_elementref.asp
#     https://www.w3schools.com/xml/schema_elements_ref.asp
#     https://www.w3schools.com/charsets/default.asp
#     https://www.w3schools.com/charsets/ref_html_ascii.asp
#     https://www.w3schools.com/charsets/ref_html_ansi.asp
#     https://www.w3schools.com/charsets/ref_html_ansi.asp
#     https://www.w3schools.com/charsets/ref_html_8859.asp
#     https://www.w3schools.com/charsets/ref_html_symbols.asp
#     https://www.w3schools.com/charsets/ref_html_utf8.asp
#     https://www.w3schools.com/exercises/index.php
#     https://www.w3schools.com/html/html_exercises.asp
#     https://www.w3schools.com/css/css_exercises.asp
#     https://www.w3schools.com/js/js_exercises.asp
#     https://www.w3schools.com/sql/sql_exercises.asp
#     https://www.w3schools.com/mysql/mysql_exercises.asp
#     https://www.w3schools.com/php/php_exercises.asp
#     https://www.w3schools.com/python/python_exercises.asp
#     https://www.w3schools.com/python/numpy/numpy_exercises.asp
#     https://www.w3schools.com/python/pandas/pandas_exercises.asp
#     https://www.w3schools.com/python/scipy/scipy_exercises.php
#     https://www.w3schools.com/jquery/jquery_exercises.asp
#     https://www.w3schools.com/java/java_exercises.asp
#     https://www.w3schools.com/bootstrap/bootstrap_exercises.asp
#     https://www.w3schools.com/bootstrap4/bootstrap_exercises.asp
#     https://www.w3schools.com/cpp/cpp_exercises.asp
#     https://www.w3schools.com/cs/cs_exercises.asp
#     https://www.w3schools.com/r/r_exercises.asp
#     https://www.w3schools.com/kotlin/kotlin_exercises.php
#     https://www.w3schools.com/go/go_exercises.php
#     https://www.w3schools.com/git/git_exercises.asp
#     https://www.w3schools.com/quiztest/default.asp
#     https://www.w3schools.com/html/html_quiz.asp
#     https://www.w3schools.com/css/css_quiz.asp
#     https://www.w3schools.com/js/js_quiz.asp
#     https://www.w3schools.com/sql/sql_quiz.asp
#     https://www.w3schools.com/mysql/mysql_quiz.asp
#     https://www.w3schools.com/php/php_quiz.asp
#     https://www.w3schools.com/python/python_quiz.asp
#     https://www.w3schools.com/python/numpy/numpy_quiz.asp
#     https://www.w3schools.com/python/pandas/pandas_quiz.asp
#     https://www.w3schools.com/python/scipy/scipy_quiz.php
#     https://www.w3schools.com/jquery/jquery_quiz.asp
#     https://www.w3schools.com/java/java_quiz.asp
#     https://www.w3schools.com/bootstrap/bootstrap_quiz.asp
#     https://www.w3schools.com/bootstrap4/bootstrap_quiz.asp
#     https://www.w3schools.com/cpp/cpp_quiz.asp
#     https://www.w3schools.com/cs/cs_quiz.asp
#     https://www.w3schools.com/r/r_quiz.asp
#     https://www.w3schools.com/xml/xml_quiz.asp
#     https://www.w3schools.com/cybersecurity/cybersecurity_quiz.php
#     https://www.w3schools.com/accessibility/accessibility_quiz.php
#     https://courses.w3schools.com/
#     https://courses.w3schools.com/courses/html
#     https://courses.w3schools.com/courses/css
#     https://courses.w3schools.com/courses/javascript
#     https://courses.w3schools.com/programs/front-end
#     https://courses.w3schools.com/courses/sql
#     https://courses.w3schools.com/courses/python
#     https://courses.w3schools.com/courses/numpy-fundamentals
#     https://courses.w3schools.com/courses/pandas-fundamentals
#     https://courses.w3schools.com/courses/jquery
#     https://courses.w3schools.com/courses/php
#     https://courses.w3schools.com/courses/c-sharp
#     https://courses.w3schools.com/courses/cplusplus
#     https://courses.w3schools.com/courses/xml
#     https://courses.w3schools.com/courses/r-fundamentals
#     https://courses.w3schools.com/courses/introduction-to-cyber-security
#     https://courses.w3schools.com/courses/accessibility-fundamentals
#     https://www.w3schools.com/html/default.asp
#     https://www.w3schools.com/tags/default.asp
#     https://www.w3schools.com/html/tryit.asp?filename=tryhtml_default
#     https://www.w3schools.com/css/default.asp
#     https://www.w3schools.com/cssref/default.asp
#     https://www.w3schools.com/css/tryit.asp?filename=trycss_default
#     https://www.w3schools.com/js/default.asp
#     https://www.w3schools.com/jsref/default.asp
#     https://www.w3schools.com/js/tryit.asp?filename=tryjs_default
#     https://www.w3schools.com/python/default.asp
#     https://www.w3schools.com/python/python_reference.asp
#     https://www.w3schools.com/python/trypython.asp?filename=demo_indentation
#     https://www.w3schools.com/sql/default.asp
#     https://www.w3schools.com/sql/sql_ref_keywords.asp
#     https://www.w3schools.com/sql/trysql.asp?filename=trysql_select_where
#     https://www.w3schools.com/php/default.asp
#     https://www.w3schools.com/jquery/default.asp
#     https://www.w3schools.com/java/default.asp
#     https://www.w3schools.com/cpp/default.asp
#     https://www.w3schools.com/w3css/default.asp
#     https://www.w3schools.com/bootstrap/default.asp
#     https://www.w3schools.com/bootstrap4/default.asp
#     https://www.w3schools.com/cs/index.php
#     https://www.w3schools.com/r/default.asp
#     https://www.w3schools.com/kotlin/index.php
#     https://www.w3schools.com/mysql/default.asp
#     https://www.w3schools.com/nodejs/default.asp
#     https://www.w3schools.com/react/default.asp
#     https://www.w3schools.com/js/js_json.asp
#     https://www.w3schools.com/angular/default.asp
#     https://www.w3schools.com/w3js/default.asp
#     https://www.w3schools.com/xml/default.asp
#     https://www.w3schools.com/sass/default.php
#     https://www.w3schools.com/icons/default.asp
#     https://www.w3schools.com/css/css_rwd_intro.asp
#     https://www.w3schools.com/graphics/default.asp
#     https://www.w3schools.com/graphics/svg_intro.asp
#     https://www.w3schools.com/graphics/canvas_intro.asp
#     https://www.w3schools.com/nodejs/nodejs_raspberrypi.asp
#     https://www.w3schools.com/cybersecurity/index.php
#     https://www.w3schools.com/colors/default.asp
#     https://www.w3schools.com/git/default.asp
#     https://www.w3schools.com/python/matplotlib_intro.asp
#     https://www.w3schools.com/python/numpy/default.asp
#     https://www.w3schools.com/python/pandas/default.asp
#     https://www.w3schools.com/python/scipy/index.php
#     https://www.w3schools.com/asp/default.asp
#     https://www.w3schools.com/accessibility/index.php
#     https://www.w3schools.com/appml/default.asp
#     https://www.w3schools.com/go/index.php
#     https://www.w3schools.com/python/python_ml_getting_started.asp
#     https://www.w3schools.com/ai/default.asp
#     https://www.w3schools.com/statistics/index.php
#     https://www.w3schools.com/datascience/default.asp
#     https://www.w3schools.com/colors/colors_picker.asp
#     https://www.w3schools.com/codegame/index.html
#     https://www.w3schools.com/codegame/index.html
#     https://www.w3schools.com/exercises/index.php
#     https://www.w3schools.com/quiztest/default.asp
#     https://www.w3schools.com/w3css/w3css_templates.asp
#     https://www.w3schools.com/w3css/w3css_templates.asp
#     https://courses.w3schools.com/
#     https://www.w3schools.com/howto/default.asp
#     https://courses.w3schools.com/
#     https://www.w3schools.com/quiztest/default.asp
#     https://www.w3schools.com/exercises/index.php
#     https://courses.w3schools.com/
#     https://www.w3schools.com/quiztest/default.asp
#     https://www.w3schools.com/exercises/index.php
#     https://www.w3schools.com/forum/default.asp
#     https://www.w3schools.com/about/default.asp
#     https://www.w3schools.com/forum/default.asp
#     https://www.w3schools.com/about/default.asp
#     https://www.linkedin.com/company/w3schools.com/
#     https://www.instagram.com/w3schools.com_official/
#     https://www.facebook.com/w3schoolscom/
#     https://www.w3schools.com/about/about_copyright.asp
#     https://www.w3schools.com/about/about_privacy.asp
#     https://www.w3schools.com/about/about_copyright.asp
#     https://shop.w3schools.com/
#   https://www.w3schools.com/html/default.asp
#     https://www.w3schools.com
#     https://profile.w3schools.com/log-in?redirect_url=https%3A%2F%2Fmy-learning.w3schools.com
#     https://courses.w3schools.com/
#     https://www.w3schools.com/default.asp
#     https://www.w3schools.com/html/default.asp
#     https://www.w3schools.com/css/default.asp
#     https://www.w3schools.com/js/default.asp
#     https://www.w3schools.com/sql/default.asp
#     https://www.w3schools.com/python/default.asp
#     https://www.w3schools.com/php/default.asp
#     https://www.w3schools.com/bootstrap/bootstrap_ver.asp
#     https://www.w3schools.com/howto/default.asp
#     https://www.w3schools.com/w3css/default.asp
#     https://www.w3schools.com/java/default.asp
#     https://www.w3schools.com/jquery/default.asp
#     https://www.w3schools.com/cpp/default.asp
#     https://www.w3schools.com/cs/index.php
#     https://www.w3schools.com/r/default.asp
#     https://www.w3schools.com/react/default.asp
#     https://www.w3schools.com/kotlin/index.php
#     https://www.w3schools.com/html/default.asp
#     https://www.w3schools.com/css/default.asp
#     https://www.w3schools.com/bootstrap/bootstrap_ver.asp
#     https://www.w3schools.com/w3css/default.asp
#     https://www.w3schools.com/colors/default.asp
#     https://www.w3schools.com/icons/default.asp
#     https://www.w3schools.com/graphics/default.asp
#     https://www.w3schools.com/graphics/svg_intro.asp
#     https://www.w3schools.com/graphics/canvas_intro.asp
#     https://www.w3schools.com/howto/default.asp
#     https://www.w3schools.com/sass/default.php
#     https://www.w3schools.com/ai/default.asp
#     https://www.w3schools.com/python/python_ml_getting_started.asp
#     https://www.w3schools.com/datascience/default.asp
#     https://www.w3schools.com/python/numpy/default.asp
#     https://www.w3schools.com/python/pandas/default.asp
#     https://www.w3schools.com/python/scipy/index.php
#     https://www.w3schools.com/python/matplotlib_intro.asp
#     https://www.w3schools.com/statistics/index.php
#     https://www.w3schools.com/xml/default.asp
#     https://www.w3schools.com/xml/ajax_intro.asp
#     https://www.w3schools.com/xml/dom_intro.asp
#     https://www.w3schools.com/xml/xml_dtd_intro.asp
#     https://www.w3schools.com/xml/schema_intro.asp
#     https://www.w3schools.com/xml/xsl_intro.asp
#     https://www.w3schools.com/xml/xpath_intro.asp
#     https://www.w3schools.com/xml/xquery_intro.asp
#     https://www.w3schools.com/js/default.asp
#     https://www.w3schools.com/jquery/default.asp
#     https://www.w3schools.com/react/default.asp
#     https://www.w3schools.com/angular/default.asp
#     https://www.w3schools.com/js/js_json_intro.asp
#     https://www.w3schools.com/js/js_ajax_intro.asp
#     https://www.w3schools.com/appml/default.asp
#     https://www.w3schools.com/w3js/default.asp
#     https://www.w3schools.com/python/default.asp
#     https://www.w3schools.com/java/default.asp
#     https://www.w3schools.com/cpp/default.asp
#     https://www.w3schools.com/cs/index.php
#     https://www.w3schools.com/r/default.asp
#     https://www.w3schools.com/kotlin/index.php
#     https://www.w3schools.com/go/index.php
#     https://www.w3schools.com/sql/default.asp
#     https://www.w3schools.com/mysql/default.asp
#     https://www.w3schools.com/php/default.asp
#     https://www.w3schools.com/asp/default.asp
#     https://www.w3schools.com/nodejs/default.asp
#     https://www.w3schools.com/nodejs/nodejs_raspberrypi.asp
#     https://www.w3schools.com/git/default.asp
#     https://www.w3schools.com/w3css/w3css_templates.asp
#     https://www.w3schools.com/browsers/default.asp
#     https://www.w3schools.com/cert/default.asp
#     https://www.w3schools.com/tryit/default.asp
#     https://www.w3schools.com/whatis/default.asp
#     https://www.w3schools.com/typingspeed/default.asp
#     https://www.w3schools.com/codegame/index.html
#     https://www.w3schools.com/cybersecurity/index.php
#     https://www.w3schools.com/accessibility/index.php
#     https://www.w3schools.com/ai/default.asp
#     https://www.w3schools.com/python/python_ml_getting_started.asp
#     https://www.w3schools.com/datascience/default.asp
#     https://www.w3schools.com/python/numpy/default.asp
#     https://www.w3schools.com/python/pandas/default.asp
#     https://www.w3schools.com/python/scipy/index.php
#     https://www.w3schools.com/python/matplotlib_intro.asp
#     https://www.w3schools.com/statistics/index.php
#     https://www.w3schools.com/xml/default.asp
#     https://www.w3schools.com/xml/ajax_intro.asp
#     https://www.w3schools.com/xml/dom_intro.asp
#     https://www.w3schools.com/xml/xml_dtd_intro.asp
#     https://www.w3schools.com/xml/schema_intro.asp
#     https://www.w3schools.com/xml/xsl_intro.asp
#     https://www.w3schools.com/xml/xpath_intro.asp
#     https://www.w3schools.com/xml/xquery_intro.asp
#     https://www.w3schools.com/tags/default.asp
#     https://www.w3schools.com/tags/ref_html_browsersupport.asp
#     https://www.w3schools.com/tags/ref_eventattributes.asp
#     https://www.w3schools.com/colors/default.asp
#     https://www.w3schools.com/tags/ref_attributes.asp
#     https://www.w3schools.com/tags/ref_canvas.asp
#     https://www.w3schools.com/graphics/svg_reference.asp
#     https://www.w3schools.com/graphics/google_maps_reference.asp
#     https://www.w3schools.com/cssref/default.asp
#     https://www.w3schools.com/cssref/css3_browsersupport.asp
#     https://www.w3schools.com/cssref/css_selectors.asp
#     https://www.w3schools.com/bootstrap/bootstrap_ref_all_classes.asp
#     https://www.w3schools.com/bootstrap4/bootstrap_ref_all_classes.asp
#     https://www.w3schools.com/w3css/w3css_references.asp
#     https://www.w3schools.com/icons/icons_reference.asp
#     https://www.w3schools.com/sass/sass_functions_string.php
#     https://www.w3schools.com/jsref/default.asp
#     https://www.w3schools.com/jsref/default.asp
#     https://www.w3schools.com/jquery/jquery_ref_overview.asp
#     https://www.w3schools.com/angular/angular_ref_directives.asp
#     https://www.w3schools.com/appml/appml_reference.asp
#     https://www.w3schools.com/w3js/w3js_references.asp
#     https://www.w3schools.com/python/python_reference.asp
#     https://www.w3schools.com/java/java_ref_keywords.asp
#     https://www.w3schools.com/sql/sql_ref_keywords.asp
#     https://www.w3schools.com/mysql/mysql_ref_functions.asp
#     https://www.w3schools.com/php/php_ref_overview.asp
#     https://www.w3schools.com/asp/asp_ref_response.asp
#     https://www.w3schools.com/xml/dom_nodetype.asp
#     https://www.w3schools.com/xml/dom_http.asp
#     https://www.w3schools.com/xml/xsl_elementref.asp
#     https://www.w3schools.com/xml/schema_elements_ref.asp
#     https://www.w3schools.com/charsets/default.asp
#     https://www.w3schools.com/charsets/ref_html_ascii.asp
#     https://www.w3schools.com/charsets/ref_html_ansi.asp
#     https://www.w3schools.com/charsets/ref_html_ansi.asp
#     https://www.w3schools.com/charsets/ref_html_8859.asp
#     https://www.w3schools.com/charsets/ref_html_symbols.asp
#     https://www.w3schools.com/charsets/ref_html_utf8.asp
#     https://www.w3schools.com/exercises/index.php
#     https://www.w3schools.com/html/html_exercises.asp
#     https://www.w3schools.com/css/css_exercises.asp
#     https://www.w3schools.com/js/js_exercises.asp
#     https://www.w3schools.com/sql/sql_exercises.asp
#     https://www.w3schools.com/mysql/mysql_exercises.asp
#     https://www.w3schools.com/php/php_exercises.asp
#     https://www.w3schools.com/python/python_exercises.asp
#     https://www.w3schools.com/python/numpy/numpy_exercises.asp
#     https://www.w3schools.com/python/pandas/pandas_exercises.asp
#     https://www.w3schools.com/python/scipy/scipy_exercises.php
#     https://www.w3schools.com/jquery/jquery_exercises.asp
#     https://www.w3schools.com/java/java_exercises.asp
#     https://www.w3schools.com/bootstrap/bootstrap_exercises.asp
#     https://www.w3schools.com/bootstrap4/bootstrap_exercises.asp
#     https://www.w3schools.com/cpp/cpp_exercises.asp
#     https://www.w3schools.com/cs/cs_exercises.asp
#     https://www.w3schools.com/r/r_exercises.asp
#     https://www.w3schools.com/kotlin/kotlin_exercises.php
#     https://www.w3schools.com/go/go_exercises.php
#     https://www.w3schools.com/git/git_exercises.asp
#     https://www.w3schools.com/quiztest/default.asp
#     https://www.w3schools.com/html/html_quiz.asp
#     https://www.w3schools.com/css/css_quiz.asp
#     https://www.w3schools.com/js/js_quiz.asp
#     https://www.w3schools.com/sql/sql_quiz.asp
#     https://www.w3schools.com/mysql/mysql_quiz.asp
#     https://www.w3schools.com/php/php_quiz.asp
#     https://www.w3schools.com/python/python_quiz.asp
#     https://www.w3schools.com/python/numpy/numpy_quiz.asp
#     https://www.w3schools.com/python/pandas/pandas_quiz.asp
#     https://www.w3schools.com/python/scipy/scipy_quiz.php
#     https://www.w3schools.com/jquery/jquery_quiz.asp
#     https://www.w3schools.com/java/java_quiz.asp
#     https://www.w3schools.com/bootstrap/bootstrap_quiz.asp
#     https://www.w3schools.com/bootstrap4/bootstrap_quiz.asp
#     https://www.w3schools.com/cpp/cpp_quiz.asp
#     https://www.w3schools.com/cs/cs_quiz.asp
#     https://www.w3schools.com/r/r_quiz.asp
#     https://www.w3schools.com/xml/xml_quiz.asp
#     https://www.w3schools.com/cybersecurity/cybersecurity_quiz.php
#     https://www.w3schools.com/accessibility/accessibility_quiz.php
#     https://courses.w3schools.com/
#     https://courses.w3schools.com/courses/html
#     https://courses.w3schools.com/courses/css
#     https://courses.w3schools.com/courses/javascript
#     https://courses.w3schools.com/programs/front-end
#     https://courses.w3schools.com/courses/sql
#     https://courses.w3schools.com/courses/python
#     https://courses.w3schools.com/courses/numpy-fundamentals
#     https://courses.w3schools.com/courses/pandas-fundamentals
#     https://courses.w3schools.com/courses/jquery
#     https://courses.w3schools.com/courses/php
#     https://courses.w3schools.com/courses/c-sharp
#     https://courses.w3schools.com/courses/cplusplus
#     https://courses.w3schools.com/courses/xml
#     https://courses.w3schools.com/courses/r-fundamentals
#     https://courses.w3schools.com/courses/introduction-to-cyber-security
#     https://courses.w3schools.com/courses/accessibility-fundamentals
#     https://www.w3schools.com/cert/default.asp
#     https://shop.w3schools.com
#     https://www.w3schools.com/html/default.asp
#     https://www.w3schools.com/html/html_intro.asp
#     https://www.w3schools.com/html/html_editors.asp
#     https://www.w3schools.com/html/html_basic.asp
#     https://www.w3schools.com/html/html_elements.asp
#     https://www.w3schools.com/html/html_attributes.asp
#     https://www.w3schools.com/html/html_headings.asp
#     https://www.w3schools.com/html/html_paragraphs.asp
#     https://www.w3schools.com/html/html_styles.asp
#     https://www.w3schools.com/html/html_formatting.asp
#     https://www.w3schools.com/html/html_quotation_elements.asp
#     https://www.w3schools.com/html/html_comments.asp
#     https://www.w3schools.com/html/html_colors.asp
#     https://www.w3schools.com/html/html_colors.asp
#     https://www.w3schools.com/html/html_colors_rgb.asp
#     https://www.w3schools.com/html/html_colors_hex.asp
#     https://www.w3schools.com/html/html_colors_hsl.asp
#     https://www.w3schools.com/html/html_css.asp
#     https://www.w3schools.com/html/html_links.asp
#     https://www.w3schools.com/html/html_links.asp
#     https://www.w3schools.com/html/html_links_colors.asp
#     https://www.w3schools.com/html/html_links_bookmarks.asp
#     https://www.w3schools.com/html/html_images.asp
#     https://www.w3schools.com/html/html_images.asp
#     https://www.w3schools.com/html/html_images_imagemap.asp
#     https://www.w3schools.com/html/html_images_background.asp
#     https://www.w3schools.com/html/html_images_picture.asp
#     https://www.w3schools.com/html/html_tables.asp
#     https://www.w3schools.com/html/html_lists.asp
#     https://www.w3schools.com/html/html_lists.asp
#     https://www.w3schools.com/html/html_lists_unordered.asp
#     https://www.w3schools.com/html/html_lists_ordered.asp
#     https://www.w3schools.com/html/html_lists_other.asp
#     https://www.w3schools.com/html/html_blocks.asp
#     https://www.w3schools.com/html/html_classes.asp
#     https://www.w3schools.com/html/html_id.asp
#     https://www.w3schools.com/html/html_iframe.asp
#     https://www.w3schools.com/html/html_scripts.asp
#     https://www.w3schools.com/html/html_filepaths.asp
#     https://www.w3schools.com/html/html_head.asp
#     https://www.w3schools.com/html/html_layout.asp
#     https://www.w3schools.com/html/html_responsive.asp
#     https://www.w3schools.com/html/html_computercode_elements.asp
#     https://www.w3schools.com/html/html5_semantic_elements.asp
#     https://www.w3schools.com/html/html5_syntax.asp
#     https://www.w3schools.com/html/html_entities.asp
#     https://www.w3schools.com/html/html_symbols.asp
#     https://www.w3schools.com/html/html_emojis.asp
#     https://www.w3schools.com/html/html_charset.asp
#     https://www.w3schools.com/html/html_urlencode.asp
#     https://www.w3schools.com/html/html_xhtml.asp
#     https://www.w3schools.com/html/html_forms.asp
#     https://www.w3schools.com/html/html_forms_attributes.asp
#     https://www.w3schools.com/html/html_form_elements.asp
#     https://www.w3schools.com/html/html_form_input_types.asp
#     https://www.w3schools.com/html/html_form_attributes.asp
#     https://www.w3schools.com/html/html_form_attributes_form.asp
#     https://www.w3schools.com/html/html5_canvas.asp
#     https://www.w3schools.com/html/html5_svg.asp
#     https://www.w3schools.com/html/html_media.asp
#     https://www.w3schools.com/html/html5_video.asp
#     https://www.w3schools.com/html/html5_audio.asp
#     https://www.w3schools.com/html/html_object.asp
#     https://www.w3schools.com/html/html_youtube.asp
#     https://www.w3schools.com/html/html5_geolocation.asp
#     https://www.w3schools.com/html/html5_draganddrop.asp
#     https://www.w3schools.com/html/html5_webstorage.asp
#     https://www.w3schools.com/html/html5_webworkers.asp
#     https://www.w3schools.com/html/html5_serversentevents.asp
#     https://www.w3schools.com/html/html_examples.asp
#     https://www.w3schools.com/html/html_quiz.asp
#     https://www.w3schools.com/html/html_exercises.asp
#     https://www.w3schools.com/html/html_exam.asp
#     https://www.w3schools.com/html/html_summary.asp
#     https://www.w3schools.com/html/html_accessibility.asp
#     https://www.w3schools.com/tags/default.asp
#     https://www.w3schools.com/tags/ref_attributes.asp
#     https://www.w3schools.com/tags/ref_standardattributes.asp
#     https://www.w3schools.com/tags/ref_html_browsersupport.asp
#     https://www.w3schools.com/tags/ref_eventattributes.asp
#     https://www.w3schools.com/tags/ref_colornames.asp
#     https://www.w3schools.com/tags/ref_canvas.asp
#     https://www.w3schools.com/tags/ref_av_dom.asp
#     https://www.w3schools.com/tags/ref_html_dtd.asp
#     https://www.w3schools.com/tags/ref_charactersets.asp
#     https://www.w3schools.com/tags/ref_urlencode.asp
#     https://www.w3schools.com/tags/ref_language_codes.asp
#     https://www.w3schools.com/tags/ref_httpmessages.asp
#     https://www.w3schools.com/tags/ref_httpmethods.asp
#     https://www.w3schools.com/tags/ref_pxtoemconversion.asp
#     https://www.w3schools.com/tags/ref_keyboardshortcuts.asp
#     https://www.w3schools.com/default.asp
#     https://www.w3schools.com/html/html_intro.asp
#     https://www.w3schools.com/html/html_intro.asp
#     https://www.w3schools.com/html/tryit.asp?filename=tryhtml_default
#     https://www.w3schools.com/html/html_examples.asp
#     https://www.w3schools.com/html/exercise.asp?filename=exercise_html_attributes1
#     https://www.w3schools.com/html/html_quiz.asp
#     https://www.w3schools.com/tags/default.asp
#     https://www.w3schools.com/tags/ref_html_browsersupport.asp
#     https://www.w3schools.com/tags/ref_attributes.asp
#     https://www.w3schools.com/tags/ref_standardattributes.asp
#     https://www.w3schools.com/tags/ref_eventattributes.asp
#     https://www.w3schools.com/tags/ref_colornames.asp
#     https://www.w3schools.com/tags/ref_canvas.asp
#     https://www.w3schools.com/tags/ref_av_dom.asp
#     https://www.w3schools.com/tags/ref_charactersets.asp
#     https://www.w3schools.com/tags/ref_urlencode.asp
#     https://www.w3schools.com/tags/ref_language_codes.asp
#     https://www.w3schools.com/tags/ref_country_codes.asp
#     https://www.w3schools.com/tags/ref_httpmessages.asp
#     https://www.w3schools.com/tags/ref_pxtoemconversion.asp
#     https://www.w3schools.com/tags/ref_keyboardshortcuts.asp
#     https://courses.w3schools.com/
#     https://www.w3schools.com/default.asp
#     https://www.w3schools.com/html/html_intro.asp
#     https://www.w3schools.com/colors/colors_picker.asp
#     https://www.w3schools.com/colors/colors_picker.asp
#     https://www.facebook.com/w3schoolscom/
#     https://www.instagram.com/w3schools.com_official/
#     https://www.linkedin.com/company/w3schools.com/
#     https://courses.w3schools.com
#     https://courses.w3schools.com
#     https://www.w3schools.com/codegame/index.html
#     https://www.w3schools.com/codegame/index.html
#     https://www.w3schools.com/codegame/index.html
#     https://www.w3schools.com/forum/default.asp
#     https://www.w3schools.com/about/default.asp
#     https://shop.w3schools.com/
#     https://www.w3schools.com/html/default.asp
#     https://www.w3schools.com/css/default.asp
#     https://www.w3schools.com/js/default.asp
#     https://www.w3schools.com/howto/default.asp
#     https://www.w3schools.com/sql/default.asp
#     https://www.w3schools.com/python/default.asp
#     https://www.w3schools.com/w3css/default.asp
#     https://www.w3schools.com/bootstrap/bootstrap_ver.asp
#     https://www.w3schools.com/php/default.asp
#     https://www.w3schools.com/java/default.asp
#     https://www.w3schools.com/cpp/default.asp
#     https://www.w3schools.com/jquery/default.asp
#     https://www.w3schools.com/tags/default.asp
#     https://www.w3schools.com/cssref/default.asp
#     https://www.w3schools.com/jsref/default.asp
#     https://www.w3schools.com/sql/sql_ref_keywords.asp
#     https://www.w3schools.com/python/python_reference.asp
#     https://www.w3schools.com/w3css/w3css_references.asp
#     https://www.w3schools.com/bootstrap/bootstrap_ref_all_classes.asp
#     https://www.w3schools.com/php/php_ref_overview.asp
#     https://www.w3schools.com/colors/colors_names.asp
#     https://www.w3schools.com/java/java_ref_keywords.asp
#     https://www.w3schools.com/angular/angular_ref_directives.asp
#     https://www.w3schools.com/jquery/jquery_ref_overview.asp
#     https://www.w3schools.com/html/html_examples.asp
#     https://www.w3schools.com/css/css_examples.asp
#     https://www.w3schools.com/js/js_examples.asp
#     https://www.w3schools.com/howto/default.asp
#     https://www.w3schools.com/sql/sql_examples.asp
#     https://www.w3schools.com/python/python_examples.asp
#     https://www.w3schools.com/w3css/w3css_examples.asp
#     https://www.w3schools.com/bootstrap/bootstrap_examples.asp
#     https://www.w3schools.com/php/php_examples.asp
#     https://www.w3schools.com/java/java_examples.asp
#     https://www.w3schools.com/xml/xml_examples.asp
#     https://www.w3schools.com/jquery/jquery_examples.asp
#     https://courses.w3schools.com/courses/html
#     https://courses.w3schools.com/courses/css
#     https://courses.w3schools.com/courses/javascript
#     https://courses.w3schools.com/programs/front-end
#     https://courses.w3schools.com/courses/sql
#     https://courses.w3schools.com/courses/python
#     https://courses.w3schools.com/courses/php
#     https://courses.w3schools.com/courses/jquery
#     https://courses.w3schools.com/courses/java
#     https://courses.w3schools.com/courses/cplusplus
#     https://courses.w3schools.com/courses/c-sharp
#     https://courses.w3schools.com/courses/xml
#     https://courses.w3schools.com/
#     https://www.w3schools.com/about/about_copyright.asp
#     https://www.w3schools.com/about/about_privacy.asp
#     https://www.w3schools.com/about/about_copyright.asp
#     https://www.w3schools.com/w3css/default.asp
#     https://www.w3schools.com
#   https://www.w3schools.com/css/default.asp
#     https://www.w3schools.com
#     https://profile.w3schools.com/log-in?redirect_url=https%3A%2F%2Fmy-learning.w3schools.com
#     https://courses.w3schools.com/
#     https://www.w3schools.com/default.asp
#     https://www.w3schools.com/html/default.asp
#     https://www.w3schools.com/css/default.asp
#     https://www.w3schools.com/js/default.asp
#     https://www.w3schools.com/sql/default.asp
#     https://www.w3schools.com/python/default.asp
#     https://www.w3schools.com/php/default.asp
#     https://www.w3schools.com/bootstrap/bootstrap_ver.asp
#     https://www.w3schools.com/howto/default.asp
#     https://www.w3schools.com/w3css/default.asp
#     https://www.w3schools.com/java/default.asp
#     https://www.w3schools.com/jquery/default.asp
#     https://www.w3schools.com/cpp/default.asp
#     https://www.w3schools.com/cs/index.php
# ...
#     https://www.w3schools.com/jsref/dom_obj_paragraph.asp
#     https://www.w3schools.com/jsref/dom_obj_param.asp
#     https://www.w3schools.com/jsref/dom_obj_pre.asp
#     https://www.w3schools.com/jsref/dom_obj_progress.asp
#     https://www.w3schools.com/jsref/dom_obj_quote.asp
#     https://www.w3schools.com/jsref/dom_obj_s.asp
#     https://www.w3schools.com/jsref/dom_obj_samp.asp
#     https://www.w3schools.com/jsref/dom_obj_script.asp
#     https://www.w3schools.com/jsref/dom_obj_section.asp
#     https://www.w3schools.com/jsref/dom_obj_select.asp
#     https://www.w3schools.com/jsref/dom_obj_small.asp
#     https://www.w3schools.com/jsref/dom_obj_source.asp
#     https://www.w3schools.com/jsref/dom_obj_span.asp
#     https://www.w3schools.com/jsref/dom_obj_strong.asp
#     https://www.w3schools.com/jsref/dom_obj_style.asp
#     https://www.w3schools.com/jsref/dom_obj_sub.asp
#     https://www.w3schools.com/jsref/dom_obj_summary.asp
#     https://www.w3schools.com/jsref/dom_obj_sup.asp
#     https://www.w3schools.com/jsref/dom_obj_table.asp
#     https://www.w3schools.com/jsref/dom_obj_tbody.asp
#     https://www.w3schools.com/jsref/dom_obj_tabledata.asp
#     https://www.w3schools.com/jsref/dom_obj_tfoot.asp
#     https://www.w3schools.com/jsref/dom_obj_tablehead.asp
#     https://www.w3schools.com/jsref/dom_obj_thead.asp
#     https://www.w3schools.com/jsref/dom_obj_tablerow.asp
#     https://www.w3schools.com/jsref/dom_obj_textarea.asp
#     https://www.w3schools.com/jsref/dom_obj_time.asp
#     https://www.w3schools.com/jsref/dom_obj_title.asp
#     https://www.w3schools.com/jsref/dom_obj_track.asp
#     https://www.w3schools.com/jsref/dom_obj_u.asp
#     https://www.w3schools.com/jsref/dom_obj_ul.asp
#     https://www.w3schools.com/jsref/dom_obj_var.asp
#     https://www.w3schools.com/jsref/dom_obj_video.asp
#     https://www.w3schools.com/jsref/obj_cssstyledeclaration.asp
#     https://www.w3schools.com/jsref/prop_cssstyle_csstext.asp
#     https://www.w3schools.com/jsref/met_cssstyle_getpropertypriority.asp
#     https://www.w3schools.com/jsref/met_cssstyle_getpropertyvalue.asp
#     https://www.w3schools.com/jsref/met_cssstyle_item.asp
#     https://www.w3schools.com/jsref/prop_cssstyle_length.asp
#     https://www.w3schools.com/jsref/prop_cssstyle_parentrule.asp
#     https://www.w3schools.com/jsref/met_cssstyle_removeproperty.asp
#     https://www.w3schools.com/jsref/met_cssstyle_setproperty.asp
#     https://www.w3schools.com/jsref/jsref_type_conversion.asp
#     https://www.w3schools.com/default.asp
#     https://www.w3schools.com/jsref/jsref_reference.asp
#     https://www.w3schools.com/jsref/jsref_obj_string.asp
#     https://www.w3schools.com/jsref/jsref_obj_number.asp
#     https://www.w3schools.com/jsref/jsref_obj_math.asp
#     https://www.w3schools.com/jsref/jsref_obj_boolean.asp
#     https://www.w3schools.com/jsref/jsref_obj_array.asp
#     https://www.w3schools.com/jsref/jsref_obj_date.asp
#     https://www.w3schools.com/jsref/jsref_classes.asp
#     https://www.w3schools.com/jsref/jsref_obj_error.asp
#     https://www.w3schools.com/jsref/jsref_obj_global.asp
#     https://www.w3schools.com/jsref/jsref_operators.asp
#     https://www.w3schools.com/jsref/jsref_obj_regexp.asp
#     https://www.w3schools.com/jsref/jsref_statements.asp
#     https://www.w3schools.com/jsref/jsref_obj_json.asp
#     https://www.w3schools.com/jsref/dom_obj_attributes.asp
#     https://www.w3schools.com/jsref/dom_obj_document.asp
#     https://www.w3schools.com/jsref/dom_obj_all.asp
#     https://www.w3schools.com/jsref/dom_obj_event.asp
#     https://www.w3schools.com/jsref/obj_events.asp
#     https://www.w3schools.com/jsref/dom_obj_htmlcollection.asp
#     https://www.w3schools.com/jsref/obj_location.asp
#     https://www.w3schools.com/jsref/obj_navigator.asp
#     https://www.w3schools.com/jsref/obj_screen.asp
#     https://www.w3schools.com/jsref/dom_obj_style.asp
#     https://www.w3schools.com/jsref/obj_window.asp
#     https://www.w3schools.com/jsref/api_console.asp
#     https://www.w3schools.com/jsref/api_geolocation.asp
#     https://www.w3schools.com/jsref/api_history.asp
#     https://www.w3schools.com/jsref/api_storage.asp
#     https://www.w3schools.com/jsref/dom_obj_anchor.asp
#     https://www.w3schools.com/jsref/dom_obj_abbr.asp
#     https://www.w3schools.com/jsref/dom_obj_address.asp
#     https://www.w3schools.com/jsref/dom_obj_area.asp
#     https://www.w3schools.com/jsref/dom_obj_article.asp
#     https://www.w3schools.com/jsref/dom_obj_aside.asp
#     https://www.w3schools.com/jsref/dom_obj_audio.asp
#     https://www.w3schools.com/jsref/dom_obj_b.asp
#     https://www.w3schools.com/jsref/dom_obj_base.asp
#     https://www.w3schools.com/jsref/dom_obj_bdo.asp
#     https://www.w3schools.com/jsref/dom_obj_blockquote.asp
#     https://www.w3schools.com/jsref/dom_obj_body.asp
#     https://www.w3schools.com/jsref/dom_obj_br.asp
#     https://www.w3schools.com/jsref/dom_obj_pushbutton.asp
#     https://www.w3schools.com/jsref/dom_obj_canvas.asp
#     https://www.w3schools.com/jsref/dom_obj_caption.asp
#     https://www.w3schools.com/jsref/dom_obj_cite.asp
#     https://www.w3schools.com/jsref/dom_obj_code.asp
#     https://www.w3schools.com/jsref/dom_obj_col.asp
#     https://www.w3schools.com/jsref/dom_obj_colgroup.asp
#     https://www.w3schools.com/jsref/dom_obj_datalist.asp
#     https://www.w3schools.com/jsref/dom_obj_dd.asp
#     https://www.w3schools.com/jsref/dom_obj_del.asp
#     https://www.w3schools.com/jsref/dom_obj_details.asp
#     https://www.w3schools.com/jsref/dom_obj_dfn.asp
#     https://www.w3schools.com/jsref/dom_obj_dialog.asp
#     https://www.w3schools.com/jsref/dom_obj_div.asp
#     https://www.w3schools.com/jsref/dom_obj_dl.asp
#     https://www.w3schools.com/jsref/dom_obj_dt.asp
#     https://www.w3schools.com/jsref/dom_obj_em.asp
#     https://www.w3schools.com/jsref/dom_obj_embed.asp
#     https://www.w3schools.com/jsref/dom_obj_fieldset.asp
#     https://www.w3schools.com/jsref/dom_obj_figcaption.asp
#     https://www.w3schools.com/jsref/dom_obj_figure.asp
#     https://www.w3schools.com/jsref/dom_obj_footer.asp
#     https://www.w3schools.com/jsref/dom_obj_form.asp
#     https://www.w3schools.com/jsref/dom_obj_head.asp
#     https://www.w3schools.com/jsref/dom_obj_header.asp
#     https://www.w3schools.com/jsref/dom_obj_heading.asp
#     https://www.w3schools.com/jsref/dom_obj_hr.asp
#     https://www.w3schools.com/jsref/dom_obj_html.asp
#     https://www.w3schools.com/jsref/dom_obj_i.asp
#     https://www.w3schools.com/jsref/dom_obj_frame.asp
#     https://www.w3schools.com/jsref/dom_obj_image.asp
#     https://www.w3schools.com/jsref/dom_obj_ins.asp
#     https://www.w3schools.com/jsref/dom_obj_button.asp
#     https://www.w3schools.com/jsref/dom_obj_checkbox.asp
#     https://www.w3schools.com/jsref/dom_obj_color.asp
#     https://www.w3schools.com/jsref/dom_obj_date.asp
#     https://www.w3schools.com/jsref/dom_obj_datetime.asp
#     https://www.w3schools.com/jsref/dom_obj_datetime-local.asp
#     https://www.w3schools.com/jsref/dom_obj_email.asp
#     https://www.w3schools.com/jsref/dom_obj_fileupload.asp
#     https://www.w3schools.com/jsref/dom_obj_hidden.asp
#     https://www.w3schools.com/jsref/dom_obj_input_image.asp
#     https://www.w3schools.com/jsref/dom_obj_month.asp
#     https://www.w3schools.com/jsref/dom_obj_number.asp
#     https://www.w3schools.com/jsref/dom_obj_password.asp
#     https://www.w3schools.com/jsref/dom_obj_radio.asp
#     https://www.w3schools.com/jsref/dom_obj_range.asp
#     https://www.w3schools.com/jsref/dom_obj_reset.asp
#     https://www.w3schools.com/jsref/dom_obj_search.asp
#     https://www.w3schools.com/jsref/dom_obj_submit.asp
#     https://www.w3schools.com/jsref/dom_obj_text.asp
#     https://www.w3schools.com/jsref/dom_obj_input_time.asp
#     https://www.w3schools.com/jsref/dom_obj_url.asp
#     https://www.w3schools.com/jsref/dom_obj_week.asp
#     https://www.w3schools.com/jsref/dom_obj_kbd.asp
#     https://www.w3schools.com/jsref/dom_obj_label.asp
#     https://www.w3schools.com/jsref/dom_obj_legend.asp
#     https://www.w3schools.com/jsref/dom_obj_li.asp
#     https://www.w3schools.com/jsref/dom_obj_link.asp
#     https://www.w3schools.com/jsref/dom_obj_map.asp
#     https://www.w3schools.com/jsref/dom_obj_mark.asp
#     https://www.w3schools.com/jsref/dom_obj_menu.asp
#     https://www.w3schools.com/jsref/dom_obj_menuitem.asp
#     https://www.w3schools.com/jsref/dom_obj_meta.asp
#     https://www.w3schools.com/jsref/dom_obj_meter.asp
#     https://www.w3schools.com/jsref/dom_obj_nav.asp
#     https://www.w3schools.com/jsref/dom_obj_object.asp
#     https://www.w3schools.com/jsref/dom_obj_ol.asp
#     https://www.w3schools.com/jsref/dom_obj_optgroup.asp
#     https://www.w3schools.com/jsref/dom_obj_option.asp
#     https://www.w3schools.com/jsref/dom_obj_output.asp
#     https://www.w3schools.com/jsref/dom_obj_paragraph.asp
#     https://www.w3schools.com/jsref/dom_obj_param.asp
#     https://www.w3schools.com/jsref/dom_obj_pre.asp
#     https://www.w3schools.com/jsref/dom_obj_progress.asp
#     https://www.w3schools.com/jsref/dom_obj_quote.asp
#     https://www.w3schools.com/jsref/dom_obj_s.asp
#     https://www.w3schools.com/jsref/dom_obj_samp.asp
#     https://www.w3schools.com/jsref/dom_obj_script.asp
#     https://www.w3schools.com/jsref/dom_obj_section.asp
#     https://www.w3schools.com/jsref/dom_obj_select.asp
#     https://www.w3schools.com/jsref/dom_obj_small.asp
#     https://www.w3schools.com/jsref/dom_obj_source.asp
#     https://www.w3schools.com/jsref/dom_obj_span.asp
#     https://www.w3schools.com/jsref/dom_obj_strong.asp
#     https://www.w3schools.com/jsref/dom_obj_style.asp
#     https://www.w3schools.com/jsref/dom_obj_sub.asp
#     https://www.w3schools.com/jsref/dom_obj_summary.asp
#     https://www.w3schools.com/jsref/dom_obj_sup.asp
#     https://www.w3schools.com/jsref/dom_obj_table.asp
#     https://www.w3schools.com/jsref/dom_obj_tbody.asp
#     https://www.w3schools.com/jsref/dom_obj_tabledata.asp
#     https://www.w3schools.com/jsref/dom_obj_tfoot.asp
#     https://www.w3schools.com/jsref/dom_obj_tablehead.asp
#     https://www.w3schools.com/jsref/dom_obj_thead.asp
#     https://www.w3schools.com/jsref/dom_obj_tablerow.asp
#     https://www.w3schools.com/jsref/dom_obj_textarea.asp
#     https://www.w3schools.com/jsref/dom_obj_time.asp
#     https://www.w3schools.com/jsref/dom_obj_title.asp
#     https://www.w3schools.com/jsref/dom_obj_track.asp
#     https://www.w3schools.com/jsref/dom_obj_u.asp
#     https://www.w3schools.com/jsref/dom_obj_ul.asp
#     https://www.w3schools.com/jsref/dom_obj_var.asp
#     https://www.w3schools.com/jsref/dom_obj_video.asp
#     https://www.w3schools.com/jsref/obj_cssstyledeclaration.asp
#     https://www.w3schools.com/jsref/jsref_type_conversion.asp
#     https://www.w3schools.com/js/default.asp
#     https://www.w3schools.com/default.asp
#     https://www.w3schools.com/jsref/jsref_reference.asp
#     https://www.w3schools.com/colors/colors_picker.asp
#     https://www.w3schools.com/colors/colors_picker.asp
#     https://www.facebook.com/w3schoolscom/
#     https://www.instagram.com/w3schools.com_official/
#     https://www.linkedin.com/company/w3schools.com/
#     https://courses.w3schools.com
#     https://courses.w3schools.com
#     https://www.w3schools.com/codegame/index.html
#     https://www.w3schools.com/codegame/index.html
#     https://www.w3schools.com/codegame/index.html
#     https://www.w3schools.com/forum/default.asp
#     https://www.w3schools.com/about/default.asp
#     https://shop.w3schools.com/
#     https://www.w3schools.com/html/default.asp
#     https://www.w3schools.com/css/default.asp
#     https://www.w3schools.com/js/default.asp
#     https://www.w3schools.com/howto/default.asp
#     https://www.w3schools.com/sql/default.asp
#     https://www.w3schools.com/python/default.asp
#     https://www.w3schools.com/w3css/default.asp
#     https://www.w3schools.com/bootstrap/bootstrap_ver.asp
#     https://www.w3schools.com/php/default.asp
#     https://www.w3schools.com/java/default.asp
#     https://www.w3schools.com/cpp/default.asp
#     https://www.w3schools.com/jquery/default.asp
#     https://www.w3schools.com/tags/default.asp
#     https://www.w3schools.com/cssref/default.asp
#     https://www.w3schools.com/jsref/default.asp
#     https://www.w3schools.com/sql/sql_ref_keywords.asp
#     https://www.w3schools.com/python/python_reference.asp
#     https://www.w3schools.com/w3css/w3css_references.asp
#     https://www.w3schools.com/bootstrap/bootstrap_ref_all_classes.asp
#     https://www.w3schools.com/php/php_ref_overview.asp
#     https://www.w3schools.com/colors/colors_names.asp
#     https://www.w3schools.com/java/java_ref_keywords.asp
#     https://www.w3schools.com/angular/angular_ref_directives.asp
#     https://www.w3schools.com/jquery/jquery_ref_overview.asp
#     https://www.w3schools.com/html/html_examples.asp
#     https://www.w3schools.com/css/css_examples.asp
#     https://www.w3schools.com/js/js_examples.asp
#     https://www.w3schools.com/howto/default.asp
#     https://www.w3schools.com/sql/sql_examples.asp
#     https://www.w3schools.com/python/python_examples.asp
#     https://www.w3schools.com/w3css/w3css_examples.asp
#     https://www.w3schools.com/bootstrap/bootstrap_examples.asp
#     https://www.w3schools.com/php/php_examples.asp
#     https://www.w3schools.com/java/java_examples.asp
#     https://www.w3schools.com/xml/xml_examples.asp
#     https://www.w3schools.com/jquery/jquery_examples.asp
#     https://courses.w3schools.com/courses/html
#     https://courses.w3schools.com/courses/css
#     https://courses.w3schools.com/courses/javascript
#     https://courses.w3schools.com/programs/front-end
#     https://courses.w3schools.com/courses/sql
#     https://courses.w3schools.com/courses/python
#     https://courses.w3schools.com/courses/php
#     https://courses.w3schools.com/courses/jquery
#     https://courses.w3schools.com/courses/java
#     https://courses.w3schools.com/courses/cplusplus
#     https://courses.w3schools.com/courses/c-sharp
#     https://courses.w3schools.com/courses/xml
#     https://courses.w3schools.com/
#     https://www.w3schools.com/about/about_copyright.asp
#     https://www.w3schools.com/about/about_privacy.asp
#     https://www.w3schools.com/about/about_copyright.asp
#     https://www.w3schools.com/w3css/default.asp
#     https://www.w3schools.com
#   https://www.w3schools.com/jsref/default.asp
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-beb436b1df2b> in <module>
# ----> 1 webdir("https://www.w3schools.com/html/",2,0)
#
# <ipython-input-27-5fe7a6f6c118> in webdir(url, depth, indent)
#      10         url_list =collector.getLinks()
#      11         for urls in url_list:
# ---> 12             webdir(urls,depth-1,indent+1)
#
# <ipython-input-27-5fe7a6f6c118> in webdir(url, depth, indent)
#       7         content = resource.read().decode()
#       8         collector = Collector(url)
# ----> 9         collector.feed(content)
#      10         url_list =collector.getLinks()
#      11         for urls in url_list:
#
# ~/opt/anaconda3/lib/python3.7/html/parser.py in feed(self, data)
#     109         """
#     110         self.rawdata = self.rawdata + data
# --> 111         self.goahead(0)
#     112
#     113     def close(self):
#
# ~/opt/anaconda3/lib/python3.7/html/parser.py in goahead(self, end)
#     169             if startswith('<', i):
#     170                 if starttagopen.match(rawdata, i): # < + letter
# --> 171                     k = self.parse_starttag(i)
#     172                 elif startswith("</", i):
#     173                     k = self.parse_endtag(i)
#
# ~/opt/anaconda3/lib/python3.7/html/parser.py in parse_starttag(self, i)
#     324                 attrvalue = attrvalue[1:-1]
#     325             if attrvalue:
# --> 326                 attrvalue = unescape(attrvalue)
#     327             attrs.append((attrname.lower(), attrvalue))
#     328             k = m.end()
#
# ~/opt/anaconda3/lib/python3.7/html/__init__.py in unescape(s)
#     120                        r'|[^\t\n\f <&#;]{1,32};?)')
#     121
# --> 122 def unescape(s):
#     123     """
#     124     Convert all named and numeric character references (e.g. &gt;, &#62;,
#
# KeyboardInterrupt:

# %% [markdown]
# # Question 8 #
# Write SQL queries on the below database table that return:<br>
# a) All the temperature data.<br>
# b) All the cities, but without repetition.<br>
# c) All the records for India.<br>
# d) All the Fall records.<br>
# e) The city, country, and season for which the average rainfall is between 200 and 400 millimeters.<br>
# f) The city and country for which the average Fall temperature is above 20 degrees, in increasing temperature order.<br>
# g) The total annual rainfall for Cairo.<br>
# h) The total rainfall for each season.<br>

# %%
 # !pip install ipython-sql
# Out:
# Collecting ipython-sql
#   Downloading ipython_sql-0.4.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: ipython>=1.0 in /Users/mengzhao/opt/anaconda3/lib/python3.7/site-packages (from ipython-sql) (7.12.0)
# Requirement already satisfied: six in /Users/mengzhao/opt/anaconda3/lib/python3.7/site-packages (from ipython-sql) (1.14.0)
# Requirement already satisfied: ipython-genutils>=0.1.0 in /Users/mengzhao/opt/anaconda3/lib/python3.7/site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: sqlalchemy>=0.6.7 in /Users/mengzhao/opt/anaconda3/lib/python3.7/site-packages (from ipython-sql) (1.3.13)
# Collecting prettytable<1
#   Downloading prettytable-0.7.2.tar.bz2 (21 kB)
# Collecting sqlparse
#   Downloading sqlparse-0.4.1-py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 2.2 MB/s eta 0:00:011
# Requirement already satisfied: backcall in /Users/mengzhao/opt/anaconda3/lib/python3.7/site-packages (from ipython>=1.0->ipython-sql) (0.1.0)
# Requirement already satisfied: setuptools>=18.5 in /Users/mengzhao/opt/anaconda3/lib/python3.7/site-packages (from ipython>=1.0->ipython-sql) (46.0.0.post20200309)
# Requirement already satisfied: appnope; sys_platform == "darwin" in /Users/mengzhao/opt/anaconda3/lib/python3.7/site-packages (from ipython>=1.0->ipython-sql) (0.1.0)
# Requirement already satisfied: pickleshare in /Users/mengzhao/opt/anaconda3/lib/python3.7/site-packages (from ipython>=1.0->ipython-sql) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/mengzhao/opt/anaconda3/lib/python3.7/site-packages (from ipython>=1.0->ipython-sql) (3.0.3)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /Users/mengzhao/opt/anaconda3/lib/python3.7/site-packages (from ipython>=1.0->ipython-sql) (4.8.0)
# Requirement already satisfied: traitlets>=4.2 in /Users/mengzhao/opt/anaconda3/lib/python3.7/site-packages (from ipython>=1.0->ipython-sql) (4.3.3)
# Requirement already satisfied: pygments in /Users/mengzhao/opt/anaconda3/lib/python3.7/site-packages (from ipython>=1.0->ipython-sql) (2.5.2)
# Requirement already satisfied: jedi>=0.10 in /Users/mengzhao/opt/anaconda3/lib/python3.7/site-packages (from ipython>=1.0->ipython-sql) (0.14.1)
# Requirement already satisfied: decorator in /Users/mengzhao/opt/anaconda3/lib/python3.7/site-packages (from ipython>=1.0->ipython-sql) (4.4.1)
# Requirement already satisfied: wcwidth in /Users/mengzhao/opt/anaconda3/lib/python3.7/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=1.0->ipython-sql) (0.1.8)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/mengzhao/opt/anaconda3/lib/python3.7/site-packages (from pexpect; sys_platform != "win32"->ipython>=1.0->ipython-sql) (0.6.0)
# Requirement already satisfied: parso>=0.5.0 in /Users/mengzhao/opt/anaconda3/lib/python3.7/site-packages (from jedi>=0.10->ipython>=1.0->ipython-sql) (0.5.2)
# Building wheels for collected packages: prettytable
#   Building wheel for prettytable (setup.py) ... done
#   Created wheel for prettytable: filename=prettytable-0.7.2-py3-none-any.whl size=13698 sha256=0260350a2e0d36116010ff368637645bb2f7273f2a6368c3da37302e7682c639
#   Stored in directory: /Users/mengzhao/Library/Caches/pip/wheels/8c/76/0b/eb9eb3da7e2335e3577e3f96a0ae9f74f206e26457bd1a2bc8
# Successfully built prettytable
# Installing collected packages: prettytable, sqlparse, ipython-sql
# Successfully installed ipython-sql-0.4.0 prettytable-0.7.2 sqlparse-0.4.1

# %%
# %%capture
# %load_ext sql
# %sql sqlite:///chinook.db

# %%
# %%sql
# CREATE TABLE rain(City varchar(100),Country varchar(100),Season varchar(100),Temperature float ,Rainfall float);
# Out:
#  * sqlite:///chinook.db
# (sqlite3.OperationalError) table rain already exists
# [SQL: CREATE TABLE rain(City varchar(100),Country varchar(100),Season varchar(100),Temperature float ,Rainfall float);]
# (Background on this error at: http://sqlalche.me/e/e3q8)

# %%
# %%sql
# INSERT INTO rain VALUES('Mumbai','India', 'Winter',24.8,5.9);
# INSERT INTO rain VALUES('Mumbai','India', 'Spring',28.4,16.2);
# INSERT INTO rain VALUES('Mumbai','India', 'Summer',27.9,1549.4);
# INSERT INTO rain VALUES('Mumbai','India', 'Fall',27.6,346.0);
# INSERT INTO rain VALUES('London','United Kingdom', 'Winter',4.2,207.7);
# INSERT INTO rain VALUES('London','United Kingdom', 'Spring',8.3,169.6);
# INSERT INTO rain VALUES('London','United Kingdom', 'Summer',15.7,157.0);
# INSERT INTO rain VALUES('London','United Kingdom', 'Fall',10.4,218.5);
# INSERT INTO rain VALUES('Cairo','Eqypt', 'Winter',13.6,16.5);
# INSERT INTO rain VALUES('Cairo','Eqypt', 'Spring',20.7,6.5);
# INSERT INTO rain VALUES('Cairo','Eqypt', 'Summer',27.7,0.1);
# INSERT INTO rain VALUES('Cairo','Eqypt', 'Fall',22.2,4.5);
# Out:
#  * sqlite:///chinook.db
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# []

# %%
# %%sql
# SELECT * FROM rain;
# Out:
#  * sqlite:///chinook.db
# Done.
# [('Mumbai', 'India', 'Winter', 24.8, 5.9),
#  ('Mumbai', 'India', 'Spring', 28.4, 16.2),
#  ('Mumbai', 'India', 'Summer', 27.9, 1549.4),
#  ('Mumbai', 'India', 'Fall', 27.6, 346.0),
#  ('London', 'United Kingdom', 'Winter', 4.2, 207.7),
#  ('London', 'United Kingdom', 'Spring', 8.3, 169.6),
#  ('London', 'United Kingdom', 'Summer', 15.7, 157.0),
#  ('London', 'United Kingdom', 'Fall', 10.4, 218.5),
#  ('Cairo', 'Eqypt', 'Winter', 13.6, 16.5),
#  ('Cairo', 'Eqypt', 'Spring', 20.7, 6.5),
#  ('Cairo', 'Eqypt', 'Summer', 27.7, 0.1),
#  ('Cairo', 'Eqypt', 'Fall', 22.2, 4.5)]

# %%
#a) All the temperature data.
# %sql SELECT Temperature FROM rain
# Out:
#  * sqlite:///chinook.db
# Done.
# [(24.8,),
#  (28.4,),
#  (27.9,),
#  (27.6,),
#  (4.2,),
#  (8.3,),
#  (15.7,),
#  (10.4,),
#  (13.6,),
#  (20.7,),
#  (27.7,),
#  (22.2,)]

# %%
#b) All the cities, but without repetition.
# %sql SELECT DISTINCT City FROM rain
# Out:
#  * sqlite:///chinook.db
# Done.
# [('Mumbai',), ('London',), ('Cairo',)]

# %%
#c) All the records for India.
# %sql SELECT * FROM rain WHERE Country ="India"
# Out:
#  * sqlite:///chinook.db
# Done.
# [('Mumbai', 'India', 'Winter', 24.8, 5.9),
#  ('Mumbai', 'India', 'Spring', 28.4, 16.2),
#  ('Mumbai', 'India', 'Summer', 27.9, 1549.4),
#  ('Mumbai', 'India', 'Fall', 27.6, 346.0)]

# %%
#d) All the Fall records.
# %sql SELECT * FROM rain WHERE Season = "Fall"
# Out:
#  * sqlite:///chinook.db
# Done.
# [('Mumbai', 'India', 'Fall', 27.6, 346.0),
#  ('London', 'United Kingdom', 'Fall', 10.4, 218.5),
#  ('Cairo', 'Eqypt', 'Fall', 22.2, 4.5)]

# %%
#e) The city, country, and season for which the average rainfall is between 200 and 400 millimeters
# %sql SELECT City,Country,Season FROM rain WHERE Rainfall BETWEEN 200 AND 400
# Out:
#  * sqlite:///chinook.db
# Done.
# [('Mumbai', 'India', 'Fall'),
#  ('London', 'United Kingdom', 'Winter'),
#  ('London', 'United Kingdom', 'Fall')]

# %%
#f) The city and country for which the average Fall temperature is above 20 degrees, in increasing temperature order.
# %sql SELECT City,Country FROM rain WHERE Season = "Fall" AND Temperature >20 ORDER by Temperature ASC
# Out:
#  * sqlite:///chinook.db
# Done.
# [('Cairo', 'Eqypt'), ('Mumbai', 'India')]

# %%
#g) The total annual rainfall for Cairo.
# %sql SELECT SUM(Rainfall) FROM rain WHERE City="Cairo"
# Out:
#  * sqlite:///chinook.db
# Done.
# [(27.6,)]

# %%
#h) The total rainfall for each season.
# %sql SELECT Season,SUM(Rainfall) FROM rain GROUP BY Season
# Out:
#  * sqlite:///chinook.db
# Done.
# [('Fall', 569.0),
#  ('Spring', 192.29999999999998),
#  ('Summer', 1706.5),
#  ('Winter', 230.1)]

# %% [markdown]
# # Question 9 #
# Suppose list words is defined as follows:<br>
# words = ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']<br>
# Write list comprehension expressions that use list words and generate the following lists:<br>
# a) ['THE', 'QUICK', 'BROWN', 'FOX', 'JUMPS', 'OVER', 'THE', 'LAZY', 'DOG']<br>
# b) ['the', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']<br>
# c) [3, 5, 5, 3, 5, 4, 3, 4, 3] (the list of lengths of words in list words).<br>
# d) [['THE', 'the', 3], ['QUICK', 'quick', 5], ['BROWN', 'brown', 5], ['FOX', 'fox', 3], ['JUMPS', 'jumps', 5], ['OVER', 'over', 4], ['THE', 'the', 3], ['LAZY', 'lazy', 4], ['DOG', 'dog', 3]] (the list containing a list for every word of list words, where each list contains the word in uppercase and lowercase and the length of the word.)<br>
# e) ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog'] (the list of words in list words containing 4 or more characters.)

# %%
words = ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']

# %%
[x.upper() for x in words]
# Out:
# ['THE', 'QUICK', 'BROWN', 'FOX', 'JUMPS', 'OVER', 'THE', 'LAZY', 'DOG']

# %%
[x.lower() for x in words]
# Out:
# ['the', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']

# %%
[len(x) for x in words]
# Out:
# [3, 5, 5, 3, 5, 4, 3, 4, 3]

# %%
[[x.upper(),x.lower(),len(x)] for x in words]
# Out:
# [['THE', 'the', 3],
#  ['QUICK', 'quick', 5],
#  ['BROWN', 'brown', 5],
#  ['FOX', 'fox', 3],
#  ['JUMPS', 'jumps', 5],
#  ['OVER', 'over', 4],
#  ['THE', 'the', 3],
#  ['LAZY', 'lazy', 4],
#  ['DOG', 'dog', 3]]

# %%
[x for x in words if len(x)>=4]
# Out:
# ['quick', 'brown', 'jumps', 'over', 'lazy']
